# %%
import pandas as pd
import numpy as np
import datetime as dt
from datetime import date, timedelta

from sqlalchemy import create_engine
from config import db_password

# %%
# set up weather history url
url = "https://api.weather.gc.ca/collections/climate-daily/items?"
suffix = "&f=json"

climate_id = "&CLIMATE_IDENTIFIER=6115529"
year_range=list(range(2013,date.today().year+1))

params={
    'CLIMATE_IDENTIFIER':6115529,
    'LOCAL_YEAR':2013
}

# %%
# https://api.weather.gc.ca/collections/climate-daily/items?CLIMATE_IDENTIFIER=6115525^ORCLIMATE_IDENTIFIER=6115529&f=json
import requests

jsons = []

for year in year_range:
    params={
        'CLIMATE_IDENTIFIER':6115529,
        'LOCAL_YEAR':year
    }
    jsons.append(pd.json_normalize(requests.get(url, params=params).json(),record_path=['features']))
    
jsons[0]
# Out:
#                      id     type                     geometry.coordinates  \
# 0      6115529.2013.1.1  Feature  [-79.30333333333333, 44.97472222222222]
# 1      6115529.2013.1.2  Feature  [-79.30333333333333, 44.97472222222222]
# 2      6115529.2013.1.3  Feature  [-79.30333333333333, 44.97472222222222]
# 3      6115529.2013.1.4  Feature  [-79.30333333333333, 44.97472222222222]
# 4      6115529.2013.1.6  Feature  [-79.30333333333333, 44.97472222222222]
# ..                  ...      ...                                      ...
# 341  6115529.2013.12.25  Feature  [-79.30333333333333, 44.97472222222222]
# 342  6115529.2013.12.26  Feature  [-79.30333333333333, 44.97472222222222]
# 343  6115529.2013.12.28  Feature  [-79.30333333333333, 44.97472222222222]
# 344  6115529.2013.12.29  Feature  [-79.30333333333333, 44.97472222222222]
# 345  6115529.2013.12.30  Feature  [-79.30333333333333, 44.97472222222222]
#
#     geometry.type properties.STATION_NAME properties.CLIMATE_IDENTIFIER  \
# ...

# %%
weather_df=pd.concat(jsons).sort_values('properties.LOCAL_DATE')
weather_df
# Out:
#                     id     type                     geometry.coordinates  \
# 0     6115529.2013.1.1  Feature  [-79.30333333333333, 44.97472222222222]
# 1     6115529.2013.1.2  Feature  [-79.30333333333333, 44.97472222222222]
# 2     6115529.2013.1.3  Feature  [-79.30333333333333, 44.97472222222222]
# 3     6115529.2013.1.4  Feature  [-79.30333333333333, 44.97472222222222]
# 4     6115529.2013.1.6  Feature  [-79.30333333333333, 44.97472222222222]
# ..                 ...      ...                                      ...
# 96   6115529.2022.4.21  Feature  [-79.30333333333333, 44.97472222222222]
# 95   6115529.2022.4.22  Feature  [-79.30333333333333, 44.97472222222222]
# 112  6115529.2022.4.23  Feature  [-79.30333333333333, 44.97472222222222]
# 113  6115529.2022.4.24  Feature  [-79.30333333333333, 44.97472222222222]
# 114  6115529.2022.4.25  Feature  [-79.30333333333333, 44.97472222222222]
#
#     geometry.type properties.STATION_NAME properties.CLIMATE_IDENTIFIER  \
# ...

# %%
# map NaN to "None"
weather_df=weather_df.replace({'None': np.nan, None:np.nan}, regex=True)
weather_df
# Out:
#                     id     type                     geometry.coordinates  \
# 0     6115529.2013.1.1  Feature  [-79.30333333333333, 44.97472222222222]
# 1     6115529.2013.1.2  Feature  [-79.30333333333333, 44.97472222222222]
# 2     6115529.2013.1.3  Feature  [-79.30333333333333, 44.97472222222222]
# 3     6115529.2013.1.4  Feature  [-79.30333333333333, 44.97472222222222]
# 4     6115529.2013.1.6  Feature  [-79.30333333333333, 44.97472222222222]
# ..                 ...      ...                                      ...
# 96   6115529.2022.4.21  Feature  [-79.30333333333333, 44.97472222222222]
# 95   6115529.2022.4.22  Feature  [-79.30333333333333, 44.97472222222222]
# 112  6115529.2022.4.23  Feature  [-79.30333333333333, 44.97472222222222]
# 113  6115529.2022.4.24  Feature  [-79.30333333333333, 44.97472222222222]
# 114  6115529.2022.4.25  Feature  [-79.30333333333333, 44.97472222222222]
#
#     geometry.type properties.STATION_NAME properties.CLIMATE_IDENTIFIER  \
# ...

# %%
weather_df.dtypes
# Out:
# id                                      object
# type                                    object
# geometry.coordinates                    object
# geometry.type                           object
# properties.STATION_NAME                 object
# properties.CLIMATE_IDENTIFIER           object
# properties.ID                           object
# properties.LOCAL_DATE                   object
# properties.PROVINCE_CODE                object
# properties.LOCAL_YEAR                    int64
# properties.LOCAL_MONTH                   int64
# properties.LOCAL_DAY                     int64
# properties.MEAN_TEMPERATURE            float64
# properties.MEAN_TEMPERATURE_FLAG        object
# properties.MIN_TEMPERATURE             float64
# properties.MIN_TEMPERATURE_FLAG         object
# properties.MAX_TEMPERATURE             float64
# properties.MAX_TEMPERATURE_FLAG         object
# properties.TOTAL_PRECIPITATION         float64
# properties.TOTAL_PRECIPITATION_FLAG     object
# ...

# %%
clean_weather_df=weather_df[['properties.LOCAL_DATE', 'properties.LOCAL_YEAR','properties.LOCAL_MONTH','properties.MEAN_TEMPERATURE','properties.MAX_TEMPERATURE','properties.MIN_TEMPERATURE']]

# %%
clean_weather_df.describe()
# Out:
#        properties.LOCAL_YEAR  properties.LOCAL_MONTH  \
# count            3153.000000             3153.000000
# mean             2017.215033                6.369807
# std                 2.766403                3.451385
# min              2013.000000                1.000000
# 25%              2015.000000                3.000000
# 50%              2017.000000                6.000000
# 75%              2020.000000                9.000000
# max              2022.000000               12.000000
#
#        properties.MEAN_TEMPERATURE  properties.MAX_TEMPERATURE  \
# count                  3105.000000                 3106.000000
# mean                      5.147150                   11.042692
# std                      11.807277                   12.370691
# min                     -29.900000                  -23.800000
# 25%                      -3.200000                    0.800000
# 50%                       5.600000                   11.200000
# ...

# %%
clean_weather_df.isna().sum()
# Out:
# properties.LOCAL_DATE           0
# properties.LOCAL_YEAR           0
# properties.LOCAL_MONTH          0
# properties.MEAN_TEMPERATURE    48
# properties.MAX_TEMPERATURE     47
# properties.MIN_TEMPERATURE     28
# dtype: int64

# %%
clean_weather_df=clean_weather_df.dropna()

# %%
clean_weather_df.describe()
# Out:
#        properties.LOCAL_YEAR  properties.LOCAL_MONTH  \
# count            3105.000000             3105.000000
# mean             2017.226731                6.354589
# std                 2.764744                3.456029
# min              2013.000000                1.000000
# 25%              2015.000000                3.000000
# 50%              2017.000000                6.000000
# 75%              2020.000000                9.000000
# max              2022.000000               12.000000
#
#        properties.MEAN_TEMPERATURE  properties.MAX_TEMPERATURE  \
# count                  3105.000000                 3105.000000
# mean                      5.147150                   11.042254
# std                      11.807277                   12.372659
# min                     -29.900000                  -23.800000
# 25%                      -3.200000                    0.800000
# 50%                       5.600000                   11.200000
# ...

# %%
clean_weather_df = clean_weather_df.rename(columns={'properties.LOCAL_DATE' : 'date',
                        'properties.LOCAL_MONTH':'month',
                        'properties.LOCAL_YEAR':'year',
                        'properties.MEAN_TEMPERATURE':'mean_temp',
                        'properties.MAX_TEMPERATURE':'max_temp',
                        'properties.MIN_TEMPERATURE':'min_temp'})
clean_weather_df
# Out:
#                     date  year  month  mean_temp  max_temp  min_temp
# 0    2013-01-01 00:00:00  2013      1      -12.6      -7.7     -17.4
# 1    2013-01-02 00:00:00  2013      1       -9.9      -5.4     -14.3
# 2    2013-01-03 00:00:00  2013      1       -8.4      -2.3     -14.4
# 3    2013-01-04 00:00:00  2013      1       -1.7       0.0      -3.4
# 4    2013-01-06 00:00:00  2013      1       -7.0       0.4     -14.3
# ..                   ...   ...    ...        ...       ...       ...
# 96   2022-04-21 00:00:00  2022      4        5.8       9.4       2.2
# 95   2022-04-22 00:00:00  2022      4        6.9      12.9       0.9
# 112  2022-04-23 00:00:00  2022      4        3.8       6.1       1.5
# 113  2022-04-24 00:00:00  2022      4       13.8      22.6       4.9
# 114  2022-04-25 00:00:00  2022      4       10.7      14.0       7.3
#
# [3105 rows x 6 columns]

# %%
clean_weather_df['date']=pd.to_datetime(clean_weather_df['date'])
clean_weather_df
# Out:
#           date  year  month  mean_temp  max_temp  min_temp
# 0   2013-01-01  2013      1      -12.6      -7.7     -17.4
# 1   2013-01-02  2013      1       -9.9      -5.4     -14.3
# 2   2013-01-03  2013      1       -8.4      -2.3     -14.4
# 3   2013-01-04  2013      1       -1.7       0.0      -3.4
# 4   2013-01-06  2013      1       -7.0       0.4     -14.3
# ..         ...   ...    ...        ...       ...       ...
# 96  2022-04-21  2022      4        5.8       9.4       2.2
# 95  2022-04-22  2022      4        6.9      12.9       0.9
# 112 2022-04-23  2022      4        3.8       6.1       1.5
# 113 2022-04-24  2022      4       13.8      22.6       4.9
# 114 2022-04-25  2022      4       10.7      14.0       7.3
#
# [3105 rows x 6 columns]

# %%
clean_weather_df.to_csv("weather_data.csv")

# %%
clean_weather_df.dtypes
# Out:
# date         datetime64[ns]
# year                  int64
# month                 int64
# mean_temp           float64
# max_temp            float64
# min_temp            float64
# dtype: object

# %%
# want to get 10 day normalization
def ten_day_normals(date_df):
    
    mean_temp = np.mean(date_df['mean_temp'])
    max_temp = max(date_df['max_temp'])
    min_temp=min(date_df['min_temp'])
    swing=max_temp-min_temp
    
    results = {
        'mean': mean_temp,
        'max': max_temp,
        'min': min_temp,
        'swing': swing
    }
    
    return results

# %%
wet_df = clean_weather_df.set_index(['date'])
wet_df
# Out:
#             year  month  mean_temp  max_temp  min_temp
# date
# 2013-01-01  2013      1      -12.6      -7.7     -17.4
# 2013-01-02  2013      1       -9.9      -5.4     -14.3
# 2013-01-03  2013      1       -8.4      -2.3     -14.4
# 2013-01-04  2013      1       -1.7       0.0      -3.4
# 2013-01-06  2013      1       -7.0       0.4     -14.3
# ...          ...    ...        ...       ...       ...
# 2022-04-21  2022      4        5.8       9.4       2.2
# 2022-04-22  2022      4        6.9      12.9       0.9
# 2022-04-23  2022      4        3.8       6.1       1.5
# 2022-04-24  2022      4       13.8      22.6       4.9
# 2022-04-25  2022      4       10.7      14.0       7.3
#
# [3105 rows x 5 columns]

# %%
# add date column
wet_df['date'] = wet_df.index
wet_df
# Out:
#             year  month  mean_temp  max_temp  min_temp       date
# date
# 2013-01-01  2013      1      -12.6      -7.7     -17.4 2013-01-01
# 2013-01-02  2013      1       -9.9      -5.4     -14.3 2013-01-02
# 2013-01-03  2013      1       -8.4      -2.3     -14.4 2013-01-03
# 2013-01-04  2013      1       -1.7       0.0      -3.4 2013-01-04
# 2013-01-06  2013      1       -7.0       0.4     -14.3 2013-01-06
# ...          ...    ...        ...       ...       ...        ...
# 2022-04-21  2022      4        5.8       9.4       2.2 2022-04-21
# 2022-04-22  2022      4        6.9      12.9       0.9 2022-04-22
# 2022-04-23  2022      4        3.8       6.1       1.5 2022-04-23
# 2022-04-24  2022      4       13.8      22.6       4.9 2022-04-24
# 2022-04-25  2022      4       10.7      14.0       7.3 2022-04-25
#
# [3105 rows x 6 columns]

# %%
# add end date
wet_df['end_date'] = wet_df['date']+timedelta(days=11)
wet_df
# Out:
#             year  month  mean_temp  max_temp  min_temp       date   end_date
# date
# 2013-01-01  2013      1      -12.6      -7.7     -17.4 2013-01-01 2013-01-12
# 2013-01-02  2013      1       -9.9      -5.4     -14.3 2013-01-02 2013-01-13
# 2013-01-03  2013      1       -8.4      -2.3     -14.4 2013-01-03 2013-01-14
# 2013-01-04  2013      1       -1.7       0.0      -3.4 2013-01-04 2013-01-15
# 2013-01-06  2013      1       -7.0       0.4     -14.3 2013-01-06 2013-01-17
# ...          ...    ...        ...       ...       ...        ...        ...
# 2022-04-21  2022      4        5.8       9.4       2.2 2022-04-21 2022-05-02
# 2022-04-22  2022      4        6.9      12.9       0.9 2022-04-22 2022-05-03
# 2022-04-23  2022      4        3.8       6.1       1.5 2022-04-23 2022-05-04
# 2022-04-24  2022      4       13.8      22.6       4.9 2022-04-24 2022-05-05
# 2022-04-25  2022      4       10.7      14.0       7.3 2022-04-25 2022-05-06
#
# [3105 rows x 7 columns]

# %%
wet_df['ten_day_mean'] = wet_df.apply(lambda df: ten_day_normals(wet_df.loc[df['date']:df['end_date']])['mean'] , axis = 1)
wet_df['ten_day_max'] = wet_df.apply(lambda df: ten_day_normals(wet_df.loc[df['date']:df['end_date']])['max'] , axis = 1)
wet_df['ten_day_min'] = wet_df.apply(lambda df: ten_day_normals(wet_df.loc[df['date']:df['end_date']])['min'] , axis = 1)
wet_df['ten_day_swing'] = wet_df.apply(lambda df: ten_day_normals(wet_df.loc[df['date']:df['end_date']])['swing'] , axis = 1)

# %%
wet_df=wet_df[['date','month','ten_day_mean','ten_day_max','ten_day_min','ten_day_swing']]
wet_df
# Out:
#                  date  month  ten_day_mean  ten_day_max  ten_day_min  \
# date
# 2013-01-01 2013-01-01      1     -6.100000          3.4        -21.7
# 2013-01-02 2013-01-02      1     -4.277778          6.8        -21.7
# 2013-01-03 2013-01-03      1     -3.377778          6.8        -21.7
# 2013-01-04 2013-01-04      1     -3.200000          6.8        -21.7
# 2013-01-06 2013-01-06      1     -4.510000          6.8        -21.7
# ...               ...    ...           ...          ...          ...
# 2022-04-21 2022-04-21      4      8.200000         22.6          0.9
# 2022-04-22 2022-04-22      4      8.800000         22.6          0.9
# 2022-04-23 2022-04-23      4      9.433333         22.6          1.5
# 2022-04-24 2022-04-24      4     12.250000         22.6          4.9
# 2022-04-25 2022-04-25      4     10.700000         14.0          7.3
#
#             ten_day_swing
# date
# 2013-01-01           25.1
# 2013-01-02           28.5
# 2013-01-03           28.5
# ...

# %%
wet_df.to_csv('../Resources/Clean Data/final_weather.csv', index=False)

# %%
# connect to PostrgreSQL
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/polypropylene_analysis_db"
engine = create_engine(db_string)

wet_df=wet_df.drop(columns='date')

wet_df.to_sql(name='weather_data', con=engine, if_exists='replace')
